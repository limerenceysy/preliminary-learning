# %%
# %matplotlib inline
import torch
import torchvision
from torch import nn
from d2l import torch as d2l

d2l.set_figsize()
content_img = d2l.Image.open('../data/nature.jpg')
d2l.plt.imshow(content_img);
len(content_img.getbands())#确是3通道无疑
# Out:
# 3

# %%
style_img = d2l.Image.open('../data/bright.jpg')
d2l.plt.imshow(style_img);
len(content_img.getbands())
# Out:
# 3

# %%
#图像预处理，将图像转变为可以训练的tensor
rgb_mean = torch.tensor([0.485, 0.456, 0.406])
rgb_std = torch.tensor([0.229, 0.224, 0.225])

#unsqueeze 函数在指定的位置插入一个新的维度，使得张量的维度增加 1
#假设 img 是一个形状为 (3, 224, 224) 的张量，表示一张 3 通道（RGB）的 224x224 图像
# 在许多情况下，模型期望输入数据的形状为 (batch_size, channels, height, width)
# 因此，我们需要在第 0 维度添加一个批量维度。
def preprocess(img,image_shape):
    transforms=torchvision.transforms.Compose([
        torchvision.transforms.Resize(image_shape),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize(mean=rgb_mean,std=rgb_std)
    ])
    return transforms(img).unsqueeze(0)

#图像后处理，将tensor变回图片
def postprocess(img):
    img = img[0].to(rgb_std.device)
    img = torch.clamp(img.permute(1, 2, 0) * rgb_std + rgb_mean, 0, 1)
    #逆标准化公式为：img=(img×rgb_std)+rgb_mean
    #进行逆标准化操作，将标准化后的图像恢复为原始像素值范围
    return torchvision.transforms.ToPILImage()(img.permute(2, 0, 1))

# %%
#从神经网络中间层的输出中提取content和style
pretrained_net = torchvision.models.vgg19(pretrained=True)
style_layers, content_layers = [0, 5, 10, 19, 28], [25]
net = nn.Sequential(*[pretrained_net.features[i] for i in
                      range(max(content_layers + style_layers) + 1)])
def extract_features(X,content_layers,style_layers):
    contents=[]
    styles=[]
    for i in range(len(net)):
        X=net[i](X)
        if i in style_layers:
            styles.append(X)
        if i in content_layers:
            contents.append(X)
    return contents,styles
# Out:
# f:\miniconda3.8_4.9.2_install\envs\my2\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# f:\miniconda3.8_4.9.2_install\envs\my2\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
#对内容图像提取内容特征
def get_contents(image_shape,device):
    content_X=preprocess(content_img,image_shape).to(device)
    contents_Y,_=extract_features(content_X,content_layers,style_layers)
    return content_X,contents_Y
#对风格图像提取风格特征
def get_styles(image_shape,device):
    style_X=preprocess(style_img,image_shape).to(device)
    _,styles_Y=extract_features(style_X,content_layers,style_layers)
    return style_X,styles_Y

# %%
#损失函数
#1.内容损失
def content_loss(Y_hat, Y):
    return torch.square(Y_hat - Y.detach()).mean()
#2风格损失
def gram(X):
    #X：输入的特征图，形状为 (batch_size, num_channels, height, width)
    #我们知道batch_size=1
    num_channels,n=X.shape[1],X.numel()//X.shape[1]
    X=X.reshape((num_channels,n))
    return torch.matmul(X,X.T)/(num_channels*n)
def style_loss(Y_hat,gram_Y):
    return torch.square(gram(Y_hat)-gram_Y.detach()).mean()
#3.全变分损失
#水平方向的总变差+垂直方向的总变差
#0将水平方向和垂直方向的总变差平均值相加，并乘以 0.5，以平衡两个方向的贡献
def tv_loss(Y_hat):
    #Y_hat[:, :, 1:, :]：提取图像张量中从第二行到最后一行的像素。
    #Y_hat[:, :, :-1, :]：提取图像张量中从第一行到倒数第二行的像素。
    #torch.abs(Y_hat[:, :, 1:, :] - Y_hat[:, :, :-1, :])：计算相邻行之间的绝对差值
    return 0.5 * (torch.abs(Y_hat[:, :, 1:, :] - Y_hat[:, :, :-1, :]).mean() +
                  torch.abs(Y_hat[:, :, :, 1:] - Y_hat[:, :, :, :-1]).mean())

# %%
#损失函数
content_weight, style_weight, tv_weight = 1, 1e3, 10

def compute_loss(X, contents_Y_hat, styles_Y_hat, contents_Y, styles_Y_gram):
    contents_l = [content_loss(Y_hat, Y) * content_weight for Y_hat, Y in zip(
        contents_Y_hat, contents_Y)]
    styles_l = [style_loss(Y_hat, Y) * style_weight for Y_hat, Y in zip(
        styles_Y_hat, styles_Y_gram)]
    tv_l = tv_loss(X) * tv_weight
    # 对所有损失求和
    l = sum(10 * styles_l + contents_l + [tv_l])
    return contents_l, styles_l, tv_l, l

# %%
class SynthesizedImage(nn.Module):
    def __init__(self, img_shape, **kwargs):
        super(SynthesizedImage, self).__init__(**kwargs)
        self.weight = nn.Parameter(torch.rand(*img_shape))

    def forward(self):
        return self.weight

def get_inits(X, device, lr, styles_Y):
    gen_img = SynthesizedImage(X.shape).to(device)
    gen_img.weight.data.copy_(X.data)
    trainer = torch.optim.Adam(gen_img.parameters(), lr=lr)
    styles_Y_gram = [gram(Y) for Y in styles_Y]
    return gen_img(), styles_Y_gram, trainer

# %%
#训练模型
def train(X,contents_Y,styles_Y,device,lr,num_epochs,lr_decay_epoch):
    X,styles_Y_gram,trainer=get_inits(X,device,lr,styles_Y)
    scheduler=torch.optim.lr_scheduler.StepLR(trainer,lr_decay_epoch,0.8)
    animator=d2l.Animator(xlabel='epoch',ylabel='loss',xlim=[10,num_epochs],legend=['content','style','tv'],ncols=2,figsize=(7,2.5))
    for epoch in range(num_epochs):
        trainer.zero_grad()
        contents_Y_hat,styles_Y_hat=extract_features(X,content_layers,style_layers)
        contents_l,styles_l,tv_l,l=compute_loss(X,contents_Y_hat,styles_Y_hat,contents_Y,styles_Y_gram)
        l.backward()
        trainer.step()
        scheduler.step()
        if (epoch+1)%10==0:
            animator.axes[1].imshow(postprocess(X))
            animator.add(epoch+1,[float(sum(contents_l)),float(sum(styles_l)),float(tv_l)])
    return X

# %%
device, image_shape = d2l.try_gpu(), (300, 450)
net = net.to(device)
content_X, contents_Y = get_contents(image_shape, device)
_, styles_Y = get_styles(image_shape, device)
output = train(content_X, contents_Y, styles_Y, device, 0.3, 500, 50)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[23], line 4
#       2 net = net.to(device)
#       3 content_X, contents_Y = get_contents(image_shape, device)
# ----> 4 _, styles_Y = get_styles(image_shape, device)
#       5 output = train(content_X, contents_Y, styles_Y, device, 0.3, 500, 50)
#
# Cell In[21], line 8, in get_styles(image_shape, device)
#       7 def get_styles(image_shape,device):
# ----> 8     style_X=preprocess(style_img,image_shape).to(device)
#       9     _,styles_Y=extract_features(style_X,content_layers,style_layers)
#      10     return style_X,styles_Y
#
# Cell In[7], line 15, in preprocess(img, image_shape)
#       9 def preprocess(img,image_shape):
#      10     transforms=torchvision.transforms.Compose([
#      11         torchvision.transforms.Resize(image_shape),
#      12         torchvision.transforms.ToTensor(),
# ...
